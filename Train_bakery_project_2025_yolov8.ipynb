# %%
from google.colab import drive
drive.mount('/content/drive/',)
# Out:
# Mounted at /content/drive/

# %%
# !pip install ultralytics==8.2.103 -q

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu124 CPU (AMD EPYC 7B12)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 39.1/107.7 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# %cd /content/drive/MyDrive/Train-bakerypj-final
# !ls
# Out:
# /content/drive/.shortcut-targets-by-id/1siZ7bF_O2y4_SkxBX2TXHvqNOUHroIOk/Train-bakerypj-final
# Bakery-1  Bakery-2  Bakery-3  Bakery-4	Bakery-5  runs

# %%
# !ls
# Out:
# Bakery-1  Bakery-2  Bakery-3  Bakery-4	Bakery-5  runs

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="9gTy69UuefAmOypXXjvg")
project = rf.workspace("faiary-aindb").project("bakery-qbgal")
version = project.version(5)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.3/83.3 kB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 16.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Bakery-5 in yolov8:: 100%|██████████| 6538/6538 [00:52<00:00, 123.45it/s]

# %%
# %cd /content/drive/MyDrive/Train-bakerypj-final/Bakery-5

# !yolo task=detect mode=train model=yolov8n.pt \
    data=/content/drive/MyDrive/Train-bakerypj-final/Bakery-5/data.yaml \
    epochs=150 batch=16 imgsz=640 \
    workers=4 \
    lr0=0.01 augment=True
# Out:
# /content/drive/.shortcut-targets-by-id/1siZ7bF_O2y4_SkxBX2TXHvqNOUHroIOk/Train-bakerypj-final/Bakery-5
# ...
# 100% 6.25M/6.25M [00:00<00:00, 200MB/s]
# New https://pypi.org/project/ultralytics/8.3.86 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# %cd /content/drive/MyDrive/Train-bakerypj-final/Bakery-5
# Out:
# /content/drive/.shortcut-targets-by-id/1siZ7bF_O2y4_SkxBX2TXHvqNOUHroIOk/Train-bakerypj-final/Bakery-5

# %%
# !yolo task=detect mode=val model=/content/drive/MyDrive/Train-bakerypj-final/Bakery-5/runs/detect/train/weights/best.pt data=data.yaml
# Out:
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu124 CPU (AMD EPYC 7B12)
# Model summary (fused): 168 layers, 3,009,548 parameters, 0 gradients, 8.1 GFLOPs
# ...
# 100% 755k/755k [00:00<00:00, 13.9MB/s]
# val: Scanning /content/drive/.shortcut-targets-by-id/1siZ7bF_O2y4_SkxBX2TXHvqNOUHroIOk/Train-bakerypj-final/Bakery-5/valid/labels.cache... 201 images, 0 backgrounds, 0 corrupt: 100% 201/201 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:40<00:00,  3.13s/it]
#                    all        201        378      0.964      0.986      0.995      0.989
#          Apple_lattice         25         25          1      0.967      0.995      0.995
#            Banana_cake         10         10      0.948          1      0.995      0.965
#      Blueberry_lattice         27         27          1      0.967      0.995      0.995
#                Brownie         11         11       0.96          1      0.995      0.995
# ...

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/Train-bakerypj-final/Bakery-5/runs/detect/train/weights/best.pt conf=0.30 source=test/images save=True
# Out:
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu124 CPU (AMD EPYC 7B12)
# Model summary (fused): 168 layers, 3,009,548 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/32 /content/drive/.shortcut-targets-by-id/1siZ7bF_O2y4_SkxBX2TXHvqNOUHroIOk/Train-bakerypj-final/Bakery-5/test/images/IMG_1807_jpg.rf.713b336bfd69eb2d3d0544f834f92ac8.jpg: 640x640 1 Taro_chiffon, 227.5ms
# image 2/32 /content/drive/.shortcut-targets-by-id/1siZ7bF_O2y4_SkxBX2TXHvqNOUHroIOk/Train-bakerypj-final/Bakery-5/test/images/IMG_1809_jpg.rf.45740c62a5862cf3de2b98af950dfe14.jpg: 640x640 1 Taro_chiffon, 163.4ms
# image 3/32 /content/drive/.shortcut-targets-by-id/1siZ7bF_O2y4_SkxBX2TXHvqNOUHroIOk/Train-bakerypj-final/Bakery-5/test/images/IMG_1869_jpg.rf.8536def41febc842f6d59eb1a1546529.jpg: 640x640 1 Macaron_matcha, 166.2ms
# ...
